# %%
# Reference : https://medium.com/@josemarcialportilla/using-python-and-auto-arima-to-forecast-seasonal-time-series-90877adff03c

# %% [markdown]
# Time Series have several key features such as trend, seasonality, and noise.

# %% [markdown]
# ARIMA model, which stands for AutoRegressive Integrated Moving Average.

# %% [markdown]
# In an ARIMA model there are 3 parameters that are used to help model the major aspects of a times series: seasonality, trend, and noise. These parameters are labeled p,d,and q.
#
# p is the parameter associated with the auto-regressive aspect of the model, which incorporates past values. For example, forecasting that if it rained a lot over the past few days, you state its likely that it will rain tomorrow as well.
#
# d is the parameter associated with the integrated part of the model, which effects the amount of differencing to apply to a time series. You can imagine an example of this as forecasting that the amount of rain tomorrow will be similar to the amount of rain today, if the daily amounts of rain have been similar over the past few days.
#
# q is the parameter associated with the moving average part of the model.

# %% [markdown]
# If our model has a seasonal component, we use a seasonal ARIMA model (SARIMA). In that case we have another set of parameters: P,D, and Q which describe the same associations as p,d, and q, but correspond with the seasonal components of the model.

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/manishanker/AutoArima-Time-Series-Blog/master/Electric_Production.csv",
                   index_col=0)
data.head()
# Out:
#             IPG2211A2N
# DATE
# 1985-01-01     72.5052
# 1985-02-01     70.6720
# 1985-03-01     62.4502
# 1985-04-01     57.4714
# 1985-05-01     55.3151

# %%
data.shape
# Out:
# (397, 1)

# %%
data.index = pd.to_datetime(data.index)

# %%
data.columns = ['Energy Production']

# %%
# %matplotlib inline
data.plot()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt  
plt.figure(figsize=(12, 8))  
result = seasonal_decompose(data, model='multiplicative')
fig = result.plot()

# %% [markdown]
# From the plot above we can clearly see the seasonal component of the data, and we can also see the separated upward trend of the data.

# %% [markdown]
# One simple approach is to perform a grid search over multiple values of p,d,q,P,D,and Q using some sort of performance criteria. The Akaike information criterion (AIC) is an estimator of the relative quality of statistical models for a given set of data

# %%
from pyramid.arima import auto_arima
stepwise_model = auto_arima(data, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1782.527, BIC=1802.280, Fit time=3.264 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=2012.117, BIC=2020.018, Fit time=0.090 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=1942.041, BIC=1957.844, Fit time=0.552 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1837.289, BIC=1853.091, Fit time=0.971 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1783.889, BIC=1807.593, Fit time=3.163 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=1920.884, BIC=1936.687, Fit time=0.855 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=1783.389, BIC=1807.093, Fit time=9.263 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1782.021, BIC=1809.675, Fit time=7.014 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1837.164, BIC=1860.868, Fit time=3.102 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1782.825, BIC=1814.430, Fit time=10.632 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=1852.588, BIC=1876.291, Fit time=2.656 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1782.073, BIC=1813.678, Fit time=9.234 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=1864.184, BIC=1883.938, Fit time=2.725 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1784.157, BIC=1819.713, Fit time=10.437 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=1770.229, BIC=1801.834, Fit time=11.147 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 1, 12); AIC=1771.287, BIC=1798.941, Fit time=6.129 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=1816.629, BIC=1844.283, Fit time=4.591 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=1771.990, BIC=1807.546, Fit time=11.551 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 1, 2, 12); AIC=1837.279, BIC=1864.934, Fit time=3.736 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=1771.105, BIC=1806.661, Fit time=9.538 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 1, 2, 12); AIC=1854.602, BIC=1878.306, Fit time=3.148 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=1773.399, BIC=1812.906, Fit time=11.253 seconds
# Total fit time: 125.119 seconds
# 1770.2288399625086

# %%
# !pip install pyramid-arima
# Out:
# Collecting pyramid-arima
# Requirement already satisfied: pandas>=0.19 in /anaconda3/lib/python3.6/site-packages (from pyramid-arima) (0.24.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /anaconda3/lib/python3.6/site-packages (from pyramid-arima) (0.10.1)
# Requirement already satisfied: Cython>=0.23 in /anaconda3/lib/python3.6/site-packages (from pyramid-arima) (0.29.12)
# Requirement already satisfied: numpy>=1.10 in /anaconda3/lib/python3.6/site-packages (from pyramid-arima) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.17 in /anaconda3/lib/python3.6/site-packages (from pyramid-arima) (0.21.1)
# Requirement already satisfied: scipy>=0.9 in /anaconda3/lib/python3.6/site-packages (from pyramid-arima) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.6/site-packages (from pandas>=0.19->pyramid-arima) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.6/site-packages (from pandas>=0.19->pyramid-arima) (2019.1)
# Requirement already satisfied: patsy>=0.4.0 in /anaconda3/lib/python3.6/site-packages (from statsmodels>=0.9.0->pyramid-arima) (0.5.1)
# Requirement already satisfied: joblib>=0.11 in /anaconda3/lib/python3.6/site-packages (from scikit-learn>=0.17->pyramid-arima) (0.13.2)
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.19->pyramid-arima) (1.12.0)
# Installing collected packages: pyramid-arima
# Successfully installed pyramid-arima-0.8.1

# %%
train = data.loc['1985-01-01':'2016-12-01']
test = data.loc['2017-01-01':]

# %%
train.shape
# Out:
# (384, 1)

# %%
train[0:10]
# Out:
#             Energy Production
# DATE
# 1985-01-01            72.5052
# 1985-02-01            70.6720
# 1985-03-01            62.4502
# 1985-04-01            57.4714
# 1985-05-01            55.3151
# 1985-06-01            58.0904
# 1985-07-01            62.6202
# 1985-08-01            63.2485
# 1985-09-01            60.5846
# 1985-10-01            56.3154

# %%
test.shape
# Out:
# (13, 1)

# %%
test[0:10]
# Out:
#             Energy Production
# DATE
# 2017-01-01           114.8505
# 2017-02-01            99.4901
# 2017-03-01           101.0396
# 2017-04-01            88.3530
# 2017-05-01            92.0805
# 2017-06-01           102.1532
# 2017-07-01           112.1538
# 2017-08-01           108.9312
# 2017-09-01            98.6154
# 2017-10-01            93.6137

# %%
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=50, method=None, order=(1, 1, 1),
#       out_of_sample_size=0, scoring='mse', scoring_args={},
#       seasonal_order=(2, 1, 2, 12), solver='lbfgs', start_params=None,
#       suppress_warnings=True, transparams=True, trend='c')

# %%
future_forecast = stepwise_model.predict(n_periods=13)
# This returns an array of predictions:>>>
print(future_forecast)
# Out:
# [120.95585223 109.87981733 100.38254332  90.56716717  92.17592454
#  103.28594092 112.97779707 112.23087913 100.95879342  91.92545297
#   95.7296424  111.20604258 120.32106996]

# %%
future_forecast = pd.DataFrame(future_forecast, index = test.index, columns=['Prediction'])
pd.concat([test,future_forecast],axis=1).plot()

# %%
plt.figure(figsize=(15, 10))  
pd.concat([data,future_forecast],axis=1).plot()
